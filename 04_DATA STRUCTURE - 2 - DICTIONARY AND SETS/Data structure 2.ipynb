# %% [markdown]
# # Creation of Dictionaries

# %% [markdown]
# ### Dictionaries in Python are data structures that store key-value pairs, allowing you to access values by their associated keys
# ### Syntax: my_dict = {'key1': 'value1', 'key2': 'value2', 'key3': 'value3'}

# %% [markdown]
# ### Basic Disctionary

# %%
# Creating a dictionary named student_info
student_info = {'name': 'Alice', 'age': 20, 'grade': 'A'}
print(student_info['name'])  # Output: Alice
print(student_info['age'])   # Output: 20
print(student_info['grade']) # Output: A
# Out:
# Alice
# 20
# A

# %% [markdown]
# ### Dictionary with Mixed Data Types

# %%
# Creating a dictionary named employee_details
employee_details = {'name': 'Bob', 'age': 30, 'department': 'HR', 'is_manager': True}
print(employee_details['name'])        # Output: Bob
print(employee_details['age'])         # Output: 30
print(employee_details['department'])  # Output: HR
print(employee_details['is_manager'])  # Output: True
# Out:
# Bob
# 30
# HR
# True

# %% [markdown]
# ### Emty Dictionary - They are often used as placeholders when you expect to populate them later in your code

# %%
# Creating an empty dictionary
empty_dict = {}

# %% [markdown]
# # Basic Operations on Dictionaries

# %% [markdown]
# ### A) Addition

# %% [markdown]
# ### student_info = {'name': 'Alice', 'age': 22, 'grade': 'A'} # Example Dictionary

# %% [markdown]
# ### Add a Key-Value Pair - You can add a new key-value pair to a dictionary by assigning a value to a new key

# %%
student_info = {'name': 'Alice', 'age': 22, 'grade': 'A'}  # Example Dictionary
student_info['city'] = 'New York'  # Add new key-value pair
print(student_info)
# Output: {'name': 'Alice', 'age': 22, 'grade': 'A', 'city': 'New York'}
# Out:
# {'name': 'Alice', 'age': 22, 'grade': 'A', 'city': 'New York'}

# %%
print(student_info['city'])
# Out:
# New York

# %% [markdown]
# ### Update - You can update a dictionary with the contents of another dictionary using the update() method:

# %%
student_info = {'name': 'Alice', 'age': 22, 'grade': 'A'} 
additional_info = {'city': 'New York', 'marks': 95}
student_info.update(additional_info) #update a dictionary
print(student_info)
# Output: {'name': 'Alice', 'age': 22, 'grade': 'A', 'city': 'New York', 'marks': 95}
# Out:
# {'name': 'Alice', 'age': 22, 'grade': 'A', 'city': 'New York', 'marks': 95}

# %% [markdown]
# ### B) Removal

# %% [markdown]
# ### The pop()- This method removes a key from the dictionary and returns its associated value. Here's how it works:

# %%
student_info = {'name': 'Alice', 'age': 22, 'grade': 'A'}  # Example Dictionary
removed_age = student_info.pop('age')  # Removes 'age' key and returns its value
print(removed_age)  # Output: 22
print(student_info)  # Output: {'name': 'Alice', 'grade': 'A'}
# Out:
# 22
# {'name': 'Alice', 'grade': 'A'}

# %% [markdown]
# ### The popitem() - This method removes and returns the last key-value pair from the dictionary as a tuple.

# %%
student_info = {'name': 'Alice', 'age': 22, 'grade': 'A'}  # Example Dictionary
removed_pair = student_info.popitem()  # Removes and returns the last key-value pair
print(removed_pair)  # Output: ('grade', 'A')
print(student_info)  # Output: {'name': 'Alice', 'age': 22}
# Out:
# ('grade', 'A')
# {'name': 'Alice', 'age': 22}

# %% [markdown]
# ### The del - This statement allows you to delete a key-value pair from a dictionary.

# %%
student_info = {'name': 'Alice', 'age': 22, 'grade': 'A'}  # Example Dictionary
del student_info['grade']  # Removes the 'grade' key and its associated value
print(student_info)  # Output: {'name': 'Alice', 'age': 22}
# Out:
# {'name': 'Alice', 'age': 22}

# %% [markdown]
# ### Checking Membership with in:The in keyword allows you to check if a key is present in a dictionary:

# %%
student_info = {'name': 'Alice', 'age': 22, 'grade': 'A'}  # Example Dictionary
is_age_present = 'age' in student_info  # Checking if 'age' is a key in the dictionary
print("Is 'age' present in the dictionary?", is_age_present)
# Output: Is 'age' present in the dictionary? True
# Out:
# Is 'age' present in the dictionary? True

# %% [markdown]
# ### The keys() - This method returns an iterable view of keys in the dictionary:

# %%
student_info = {'name': 'Alice', 'age': 22, 'grade': 'A'}  # Example Dictionary
keys = student_info.keys()  # Returns an iterable view of keys
print("Keys in the dictionary:", list(keys))  # Converting iterable view to a list for printing
# Output: Keys in the dictionary: ['name', 'age', 'grade']
# Out:
# Keys in the dictionary: ['name', 'age', 'grade']

# %% [markdown]
# ### The values() - This method returns an iterable view of values in the dictionary:

# %%
student_info = {'name': 'Alice', 'age': 22, 'grade': 'A'}  # Example Dictionary
values = student_info.values()  # Returns an iterable view of values
print("Values in the dictionary:", list(values))  # Converting iterable view to a list for printing
# Output: Values in the dictionary: ['Alice', 22, 'A']
# Out:
# Values in the dictionary: ['Alice', 22, 'A']

# %% [markdown]
# ### The items() - This method returns an iterable view of key-value associations (as tuples) in the dictionary

# %%
student_info = {'name': 'Alice', 'age': 22, 'grade': 'A'}  # Example Dictionary
items = student_info.items()  # Returns an iterable view of key-value associations
print("Key-Value Associations in the dictionary:", list(items))  # Converting iterable view to a list for printing
# Output: Key-Value Associations in the dictionary: [('name', 'Alice'), ('age', 22), ('grade', 'A')]
# Out:
# Key-Value Associations in the dictionary: [('name', 'Alice'), ('age', 22), ('grade', 'A')]

# %% [markdown]
# # Manipulating Dictionaries

# %% [markdown]
# ### Sorting Dictionary - Sorting of data reduce the complexity of the data and make queries faster and more efficient.

# %% [markdown]
# ### Sorting Dictionaries by Keys:
# ### To sort a dictionary by keys, you can use the sorted() function along with the items() method to sort the dictionary items (key-value pairs) and then construct a new dictionary from the sorted items:

# %%
student_info = {'name': 'Alice', 'age': 22, 'grade': 'A'}  # Example Dictionary
sorted_dict = dict(sorted(student_info.items()))  
print(sorted_dict)
# Output: {'age': 22, 'grade': 'A', 'name': 'Alice'}

# %% [markdown]
# ### Copying Dictionaries - To create a copy of a dictionary, you can use the copy() method

# %%
student_info = {'name': 'Alice', 'age': 22, 'grade': 'A'}  # Example Dictionary
student_info_copy = student_info.copy()
print(student_info_copy)
# Output: {'name': 'Alice', 'age': 22, 'grade': 'A'}
# Out:
# {'name': 'Alice', 'age': 22, 'grade': 'A'}

# %% [markdown]
# ### Nesting Dictionaries - You can nest dictionaries by having a key in a dictionary refer to another dictionary:

# %%
nested_dict = {'person': {'name': 'Alice', 'age': 25, 'city': 'Chicago'}}
print(nested_dict)
# Output: {'person': {'name': 'Alice', 'age': 25, 'city': 'Chicago'}}
# Out:
# {'person': {'name': 'Alice', 'age': 25, 'city': 'Chicago'}}

# %% [markdown]
# # Dictionary Comprehension

# %% [markdown]
# ### Concise Creation of Dictionaries:Dictionary comprehension is a concise and elegant way to create dictionaries in Python.

# %% [markdown]
# ### Syntax for Dictionary Comprehension:
# ### The general syntax is {key_expression: value_expression for item in iterable}.

# %% [markdown]
# ### Example

# %% [markdown]
# ### Creating a dictionary with numbers as keys and their squares as values using dictionary comprehension

# %%
# Creating a dictionary with numbers as keys and their squares as values using dictionary comprehension
square_dict = {x: x**2 for x in range(1, 6)}  

# Printing the resulting dictionary
print(square_dict)
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25}

# %% [markdown]
# ### Creating a dictionary with numbers as keys and their cubes as values using dictionary comprehension

# %%
# Creating a dictionary with numbers as keys and their cubes as values using dictionary comprehension
cube_dict = {num: num**3 for num in range(1, 6)}

# Printing the resulting dictionary
print(cube_dict)
# Out:
# {1: 1, 2: 8, 3: 27, 4: 64, 5: 125}

# %% [markdown]
# ### Using dictionary comprehension to create a dictionary mapping words to their lengths

# %%
# Using dictionary comprehension to create a dictionary mapping words to their lengths
words = ['apple', 'banana', 'orange']
word_lengths = {word: len(word) for word in words}
print(word_lengths)
# Out:
# {'apple': 5, 'banana': 6, 'orange': 6}

# %% [markdown]
# ### Using dictionary comprehension to create a dictionary from two lists

# %%
{'name': 'Alice', 'age': 25, 'city': 'New York'}

# %%
{key[i]:value[i] for i in range(len(key))}

# %%
# Using dictionary comprehension to create a dictionary from two lists
keys = ['name', 'age', 'city']
values = ['Alice', 25, 'New York']

# Creating a dictionary where elements from the 'keys' list are keys 
# and elements from the 'values' list are values, using dictionary comprehension
info_dict = {keys[i]: values[i] for i in range(len(keys))}

# Printing the resulting dictionary
print(info_dict)
# Out:
# {'name': 'Alice', 'age': 25, 'city': 'New York'}

# %% [markdown]
# Question 1: You are provided with a dictionary containing employee names and their corresponding monthly salaries.
# Find and display the highest salary in the company. Calculate and print the average salary of all employees.
#  Identify and display the names of employees who earn above a certain threshold (e.g., $5000).
#   Sort and display the employee names in alphabetical order.
#
#
# employees = {
#     "Alice": {"salary": 5000, "age": 28},
#     "Bob": {"salary": 6000, "age": 34},
#     "Charlie": {"salary": 5500, "age": 30}
# }

# %%
employees = {
    "Alice": {"salary": 5000, "age": 28},
    "Bob": {"salary": 6000, "age": 34},
    "Charlie": {"salary": 5500, "age": 30}
}

max_salary = 0
max_salary_employee_name = ''
for emp_name, emp_value in employees.items():
    print(emp_name)
    for val in emp_value:
        if max_salary < emp_value[val]:
            max_salary = emp_value[val]
            max_salary_employee_name = emp_name

print(max_salary_employee_name)
# Out:
# Alice
# Bob
# Charlie
# Bob

# %%
employee_dict ={"A":2000,"C":6000,"E":5000,"D":7000,"B":3000}
max_value = employee_dict["A"]
for emp in employee_dict:
    if employee_dict[emp] > max_value:
        max_value = employee_dict[emp]

for key, value in employee_dict.items():
    if value == max_value:
        print(key)


total_employee  = len(employee_dict)
sum = 0 
for val in employee_dict.values():
    sum = sum+val

print(sum/total_employee)
max_employee = []
for key, value in employee_dict.items():
    if value > 5000:
        max_employee.append(key)
print(max_employee)

sorted_employee_name = sorted(employee_dict)
print(sorted_employee_name)

sorted_dict ={}
for emp in sorted_employee_name:
    sorted_dict[emp] = employee_dict[emp]

print(sorted_dict)
# Out:
# D
# 4600.0
# ['C', 'D']
# ['A', 'B', 'C', 'D', 'E']
# {'A': 2000, 'B': 3000, 'C': 6000, 'D': 7000, 'E': 5000}

# %% [markdown]
# Question 2: Extend the dictionary to include the age of each employee.
#  Find and display the oldest employee in the company.
# Calculate and print the average age of all employees.
#  Identify and display the names of employees who are younger than a certain age (e.g., 30).
# Sort and display the employee names based on age in ascending order.

# %% [markdown]
# Add a new key to the dictionary to represent the performance rating of each employee (on a scale of 1 to 10).
# Identify and display the names of employees with the highest performance rating.
# Calculate and print the average performance rating of all employees.
# Identify and display the names of employees with a rating above a certain threshold (e.g., 8).

# %%
{
 "Alice": {"salary": 5000, "age": 28, "rating": 9},
 "Bob": {"salary": 6000, "age": 34, "rating": 7},
 "Charlie": {"salary": 5500, "age": 30, "rating": 10},
 "David": {"salary": 7000, "age": 40, "rating": 8}
}
# Out:
# 7000

# %%
##1 .
max_rating = max(emp["rating"] for emp in employees.values())

top_employees = [name for name, emp in employees.items() if emp["rating"] == max_rating]

##2.
avg_rating = sum(emp["rating"] for emp in employees.values()) / len(employees)


##3.
threshold = 8
above_threshold = [name for name, emp in employees.items() if emp["rating"] > threshold]

# %% [markdown]
# # Creation of sets

# %% [markdown]
# ### A set in Python is an unordered collection of unique elements.

# %% [markdown]
# ### The syntax for creating sets in Python is by using curly braces {} or the set() constructor.

# %% [markdown]
# ### Basic Set Creation

# %%
# Basic set creation with curly braces
colors = {'red', 'green', 'blue', 'yellow'}
print(colors)
# Out:
# {'yellow', 'red', 'green', 'blue'}

# %% [markdown]
# ### Set with Mixed Data Types

# %%
# Set with mixed data types
mixed_set = {1, 'apple', 3.14, (1, 2, 3)}
print(mixed_set)
# Out:
# {1, 3.14, (1, 2, 3), 'apple'}

# %% [markdown]
# ### Using set() Constructor

# %%
# Creating a set using the set() constructor with a list
fruits_set = set(['apple', 'banana', 'orange'])
print(fruits_set)
# Out:
# {'banana', 'orange', 'apple'}

# %% [markdown]
# # Operations on Sets

# %% [markdown]
# ### A) Addition
# ### my_set = {1, 2, 3, 4, 5}

# %% [markdown]
# ### Update - The update() method adds elements from another iterable (such as a set, list, or tuple) to the set:

# %%
# Initial set
my_set = {1, 2, 3, 4, 5}

# Set to update from
set_to_update = {5, 6, 7}

# Using the update() method to add elements from set_to_update to my_set
my_set.update(set_to_update)

# Printing the resulting set
print(my_set)
# Out:
# {1, 2, 3, 4, 5, 6, 7}

# %% [markdown]
# ### Add - The add() method adds a single element to the set:

# %%
# Initial set
my_set = {1, 2, 3, 4, 5}

# Adding a new element (8) to the set using the add() method
my_set.add(10)

# Printing the resulting set
print(my_set)
# Out:
# {1, 2, 3, 4, 5, 10}

# %%
seta={1,23,44,4454,2323}
seta.add(10)
print(seta)
# Out:
# {1, 2323, 4454, 23, 10, 44}

# %% [markdown]
# ### B) Removal

# %% [markdown]
# ### Remove - method to remove a specific element from a set.

# %%
# Initial set
my_set = {1, 2, 3, 4, 5}

# Removing the element '3' from the set using the remove method
# The remove() method removes a specified element from the set.
my_set.remove(3)

# Printing the set after removal
print("Set after removing element '3':", my_set)
# Out:
# Set after removing element '3': {1, 2, 4, 5}

# %% [markdown]
# ### Pop - method to remove and return an arbitrary element from a set.

# %%
# Initial set
my_set = {1, 2, 3, 4, 5}

# Popping an arbitrary element from the set using the pop method
# The pop() method removes and returns an arbitrary element from the set.
popped_element = my_set.pop()

# Printing the popped element and the set after popping
print("Popped element:", popped_element)
print("Set after popping:", my_set)
# Out:
# Popped element: 1
# Set after popping: {2, 3, 4, 5}

# %% [markdown]
# ### C) Additional Operations

# %% [markdown]
# ### Checking Membership - The 'in' operator checks if a specified element is present in the set.

# %%
# Initial set
my_set = {1, 2, 3, 4, 5}

# Checking if an element (4) is present in the set using the 'in' operator
# The 'in' operator checks if a specified element is present in the set.
is_four_present = 4 in my_set

# Printing the result
print("Is 4 present in the set?", is_four_present)
# Out:
# Is 4 present in the set? True

# %% [markdown]
# # Manipulating Sets

# %% [markdown]
# ### Set operations refer to various mathematical operations performed on sets

# %% [markdown]
# ### Union (|): Combines elements from two sets, resulting in a new set containing all unique elements from both sets.

# %%
# Two sets for demonstration
set1 = {1, 2, 3}
set2 = {3, 4, 5}

# Union operation using the '|' operator
# The '|' operator computes the union of two sets, which is a set containing all distinct elements from both sets.
union_result = set1 | set2  # Result: {1, 2, 3, 4, 5}

# Printing the result
print("Union of set1 and set2:", union_result)
# Out:
# Union of set1 and set2: {1, 2, 3, 4, 5}

# %% [markdown]
# ### Intersection (&): Computes the set of elements that are common to both sets, resulting in a new set containing only elements that exist in both sets.

# %%
# Two sets for demonstration
set1 = {1, 2, 3}
set2 = {3, 4, 5}

# Intersection operation using the '&' operator
# The '&' operator computes the intersection of two sets, resulting in a new set containing elements that are common to both sets.
intersection_result = set1 & set2  # Result: {3}

# Printing the result
print("Intersection of set1 and set2:", intersection_result)
# Out:
# Intersection of set1 and set2: {3}

# %% [markdown]
# ### Difference (-): Computes the set of elements that are in one set but not the other, resulting in a new set containing elements that are unique to the first set.

# %%
# Two sets for demonstration
set1 = {1, 2, 3}
set2 = {3, 4, 5}

# Difference operation using the '-' operator
# The '-' operator computes the set of elements that are in set1 but not in set2, resulting in a new set containing elements that are unique to set1.
difference_result = set1 - set2  # Result: {1, 2}

# Printing the result
print("Difference between set1 and set2:", difference_result)
# Out:
# Difference between set1 and set2: {1, 2}

# %% [markdown]
# ### Checking Membership - in operator to check for the presence of an element in a set.

# %%
# Define the fruit_set
fruit_set = {'apple', 'banana', 'orange'}

# Checking if the element 'banana' is present in the set fruit_set
# Returns True if 'banana' is in the set, otherwise returns False
is_present = 'banana' in fruit_set

# Printing the result
print("Is 'banana' present in the set?", is_present)
# Out:
# Is 'banana' present in the set? True

# %% [markdown]
# ## Common Operations on Both Dictionaries and Sets

# %% [markdown]
# ### Dictionary : Iterating Over Items

# %%
# Example dictionary
my_dict = {'name': 'Alice', 'age': 25, 'city': 'New York'}

# Iterating over items in the dictionary using the items() method
# The items() method returns a view object that displays a list of a dictionary's key-value pairs as tuples.
# In each iteration, 'key' and 'value' represent the key-value pair of the dictionary.
for key, value in my_dict.items():
    print(key, value)
# Out:
# name Alice
# age 25
# city New York

# %% [markdown]
# ### Set : Iterating Over Items

# %%
# Example set
my_set = {1, 2, 3, 4, 5}

# Iterating over elements in the set using a for loop
# In each iteration, 'element' represents an element of the set.
for element in my_set:
    print(element)
# Out:
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# ### Checking Membership

# %%
# Checking if 'key' is a key in the dictionary my_dict
# Returns True if 'key' is a key in the dictionary, otherwise returns False
is_present = 'key' in my_dict

# Checking if 'element' is in the set my_set
# Returns True if 'element' is in the set, otherwise returns False
is_present_set = 'element' in my_set

# Printing the results
print("Is 'key' present in the dictionary?", is_present)
print("Is 'element' present in the set?", is_present_set)
# Out:
# Is 'key' present in the dictionary? False
# Is 'element' present in the set? False

# %% [markdown]
# ### Intersection and Differences

# %% [markdown]
#  ### Intersection identifies what is common, while differences reveal what is unique to each set or dictionary. These operations are useful for comparing and analyzing data structures, identifying shared or unique elements, and performing various set-based operations.

# %% [markdown]
# ### Dictionaries (Keys)

# %%
# Define two dictionaries
dict1 = {'a': 1, 'b': 2, 'c': 3}
dict2 = {'b': 4, 'c': 5, 'd': 6}

# Define two sets
set1 = {1, 2, 3, 4, 5}
set2 = {4, 5, 6, 7, 8}

# Dictionaries (Keys):
# Intersection of keys between two dictionaries
common_keys = dict1.keys() & dict2.keys()
print("Common keys between dict1 and dict2:", common_keys)
# Out:
# Common keys between dict1 and dict2: {'b', 'c'}

# %% [markdown]
# ### Sets

# %%
# Define two dictionaries
dict1 = {'a': 1, 'b': 2, 'c': 3}
dict2 = {'b': 4, 'c': 5, 'd': 6}

# Define two sets
set1 = {1, 2, 3, 4, 5}
set2 = {4, 5, 6, 7, 8}

# Sets:
# Common elements between two sets
set_intersection = set1 & set2
print("Common elements between set1 and set2:", set_intersection)

# Elements in set1 but not in set2
set_difference = set1 - set2
print("Elements in set1 but not in set2:", set_difference)
# Out:
# Common elements between set1 and set2: {4, 5}
# Elements in set1 but not in set2: {1, 2, 3}

# %% [markdown]
# You have a set representing students enrolled in a Computer Science course.
# Update the set with students from the Mathematics course. Create a copy of the set.
#  Add a new student who just joined the course.
#   Remove a student who dropped the course (handle the case where the student is not in the set).
# Discard a student who is not actively participating (no error if the student is not present).
#  Clear all students from the set.

# %%
computer = {"Alice","Bob","Charlie"}
mathematics = {"John","Doe"}

computer.update(mathematics)
computer_copy = computer

computer_copy.add('Joseph')
computer_copy

print('Sai' in computer_copy)
if 'John' in computer_copy:
    computer_copy.remove('John')

computer_copy ={}
computer_copy
# Out:
# False
# {}

# %% [markdown]
#  You have a dictionary representing the catalog of books in the library.
#   Display the details (title and author) of each book in the catalog.
#    Check if a specific book is in the catalog.
#    Add a new book to the catalog.
#     Remove a book from the catalog (handle the case where the book is not present).
#      Update the details of a book in the catalog.

# %%
library_catalog = {
    "B001": {
        "title": "To Kill a Mockingbird",
        "author": "Harper Lee",
        "year": 1960,
        "genre": "Fiction",
        "available": True
    },
    "B002": {
        "title": "1984",
        "author": "George Orwell",
        "year": 1949,
        "genre": "Dystopian",
        "available": False
    },
    "B003": {
        "title": "The Great Gatsby",
        "author": "F. Scott Fitzgerald",
        "year": 1925,
        "genre": "Classic",
        "available": True
    }
}


for key,value in library_catalog.items():
    print(f"Book Catalogue is {key}")
    for val in value:
        if val == 'title':
            print(f"Title name is {value[val]}")
        elif val == 'author':
            print(f"Author name is {value[val]}")
# Out:
# Book Catalogue is B001
# Title name is To Kill a Mockingbird
# Author name is Harper Lee
# Book Catalogue is B002
# Title name is 1984
# Author name is George Orwell
# Book Catalogue is B003
# Title name is The Great Gatsby
# Author name is F. Scott Fitzgerald

# %%
library_catalog = {
    "B001": {
        "title": "To Kill a Mockingbird",
        "author": "Harper Lee",
        "year": 1960,
        "genre": "Fiction",
        "available": True
    },
    "B002": {
        "title": "1984",
        "author": "George Orwell",
        "year": 1949,
        "genre": "Dystopian",
        "available": False
    },
    "B003": {
        "title": "The Great Gatsby",
        "author": "F. Scott Fitzgerald",
        "year": 1925,
        "genre": "Classic",
        "available": True
    }
}


for key,value in library_catalog.items():
    #print(f"Book Catalogue is {key}")
    for key1,value1 in value.items():
       if value1=='1984':
           print(value[key1],key)



new_dict =  {"B004": {
        "title": "Harry Potter",
        "author": "J.B Rowling",
        "year": 1940,
        "genre": "Fantasy",
        "available": True
    }
}

library_catalog.update(new_dict)
library_catalog
# Out:
# 1984 B002
# {'B001': {'title': 'To Kill a Mockingbird',
#   'author': 'Harper Lee',
#   'year': 1960,
#   'genre': 'Fiction',
#   'available': True},
#  'B002': {'title': '1984',
#   'author': 'George Orwell',
#   'year': 1949,
#   'genre': 'Dystopian',
#   'available': False},
#  'B003': {'title': 'The Great Gatsby',
#   'author': 'F. Scott Fitzgerald',
#   'year': 1925,
#   'genre': 'Classic',
#   'available': True},
#  'B004': {'title': 'Harry Potter',
#   'author': 'J.B Rowling',
#   'year': 1940,
#   'genre': 'Fantasy',
#   'available': True}}

# %%
del_key = ''
for lib_key,lib_val in library_catalog.items():
    for key,value in lib_val.items():
        if value =='Harry Potter':
            print(f'Present in {lib_key}')
            del_key = lib_key

del_key

del library_catalog[del_key]
# Out:
# Present in B004

# %%
library_catalog
# Out:
# {'B001': {'title': 'To Kill a Mockingbird',
#   'author': 'Harper Lee',
#   'year': 1960,
#   'genre': 'Fiction',
#   'available': True},
#  'B002': {'title': '1984',
#   'author': 'George Orwell',
#   'year': 1949,
#   'genre': 'Dystopian',
#   'available': False},
#  'B003': {'title': 'The Great Gatsby',
#   'author': 'F. Scott Fitzgerald',
#   'year': 1925,
#   'genre': 'Classic',
#   'available': True}}

# %%
new_dict =  {"B004": {
        "title": "Harry Potter",
        "author": "J.B Rowling",
        "year": 1940,
        "genre": "Fantasy",
        "available": True
    }
}

library_catalog.update(new_dict)
library_catalog
# Out:
# {'B001': {'title': 'To Kill a Mockingbird',
#   'author': 'Harper Lee',
#   'year': 1960,
#   'genre': 'Fiction',
#   'available': True},
#  'B002': {'title': '1984',
#   'author': 'George Orwell',
#   'year': 1949,
#   'genre': 'Dystopian',
#   'available': False},
#  'B003': {'title': 'The Great Gatsby',
#   'author': 'F. Scott Fitzgerald',
#   'year': 1925,
#   'genre': 'Classic',
#   'available': True},
#  'B004': {'title': 'Harry Potter',
#   'author': 'J.B Rowling',
#   'year': 1940,
#   'genre': 'Fantasy',
#   'available': True}}

# %%
for lib_key,lib_val in library_catalog.items():
    if lib_key=='B004':
        for key in lib_val:
            if key == 'year':
                lib_val['year'] = 1997

# %%
library_catalog
# Out:
# {'B001': {'title': 'To Kill a Mockingbird',
#   'author': 'Harper Lee',
#   'year': 1960,
#   'genre': 'Fiction',
#   'available': True},
#  'B002': {'title': '1984',
#   'author': 'George Orwell',
#   'year': 1949,
#   'genre': 'Dystopian',
#   'available': False},
#  'B003': {'title': 'The Great Gatsby',
#   'author': 'F. Scott Fitzgerald',
#   'year': 1925,
#   'genre': 'Classic',
#   'available': True},
#  'B004': {'title': 'Harry Potter',
#   'author': 'J.B Rowling',
#   'year': 1997,
#   'genre': 'Fantasy',
#   'available': True}}

# %%
# Library system with books and members
library_system = {
    "books": library_catalog,
    "members": {"Alice", "Bob", "Charlie", "Diana"}
}

library_system
# Out:
# {'books': {'B001': {'title': 'To Kill a Mockingbird',
#    'author': 'Harper Lee',
#    'year': 1960,
#    'genre': 'Fiction',
#    'available': True},
#   'B002': {'title': '1984',
#    'author': 'George Orwell',
#    'year': 1949,
#    'genre': 'Dystopian',
#    'available': False},
#   'B003': {'title': 'The Great Gatsby',
#    'author': 'F. Scott Fitzgerald',
#    'year': 1925,
#    'genre': 'Classic',
#    'available': True},
#   'B004': {'title': 'Harry Potter',
#    'author': 'J.B Rowling',
#    'year': 1997,
#    'genre': 'Fantasy',
#    'available': True}},
#  'members': {'Alice', 'Bob', 'Charlie', 'Diana'}}

# %%
# Library catalog (same as before)
library_catalog = {
    'B001': {'title': 'To Kill a Mockingbird', 'author': 'Harper Lee', 'year': 1960, 'genre': 'Fiction', 'available': True},
    'B002': {'title': '1984', 'author': 'George Orwell', 'year': 1949, 'genre': 'Dystopian', 'available': False},
    'B003': {'title': 'The Great Gatsby', 'author': 'F. Scott Fitzgerald', 'year': 1925, 'genre': 'Classic', 'available': True},
    'B004': {'title': 'Harry Potter', 'author': 'J.B Rowling', 'year': 1997, 'genre': 'Fantasy', 'available': True}
}

# Library members (set)
library_members = {"Alice", "Bob", "Charlie", "Diana"}

# Borrowed books dictionary
borrowed_books = {
    "Alice": ["B002"],                # Alice borrowed "1984"
    "Bob": ["B001", "B003"],          # Bob borrowed "To Kill a Mockingbird" & "The Great Gatsby"
    "Charlie": [],                    # Charlie hasn’t borrowed any books
    "Diana": ["B004"]                 # Diana borrowed "Harry Potter"
}

# Display borrowed books
print("Borrowed Books:")
for member, books in borrowed_books.items():
    book_titles = [library_catalog[book_id]['title'] for book_id in books]
    print(f"{member}: {book_titles}")
